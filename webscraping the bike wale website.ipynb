# %% [markdown]
# # WEB SCARPING THE BIKE WALE WEBSITE
#
#
# > About the Project- This is a small part of work in the data analysis web scarping. By the Webscarping we can extract the data set from HTML to required formate.
# Here this conversion we can understand the current market prices of the bikes rescpect brands. and we can draw conclusion by proper approach.
#
# > Below I have built a one time function for each brand to extract the data into data frame quickly.we can understand to scrolling down.Like Hero, Honda, Royal Enfield etc.

# %%
import requests
from bs4 import BeautifulSoup
#_______________________________

import pandas as pd
import warnings
warnings.filterwarnings('ignore')
#________________________________

from collections import OrderedDict

# %%
def page_url(url_link):
    req_ = requests.get(url_link)                                                                #step 1
    page = BeautifulSoup(req_.content,'lxml')
#________________________________________________________________________________________
    bike_name = page.find_all('h3',class_='bikeTitle margin-bottom10')
    name_list = [p.text for p in bike_name]                                                      #step 2
#_________________________________________________________________________________________
    specf = page.find_all('div',class_='text-xt-light-grey font14 margin-bottom15')
    specifications = [p.text.strip() for p in specf]                                             #step 3
#________________________________________________________________________________________
    prices = page.find_all('div',class_='text-bold')
    prices_ = [p.text for p in prices] #1
    prices__= OrderedDict.fromkeys(prices_) #2                                                   #step 4
    prices___ = list(prices__.keys()) #3        
    prices___.remove('AD')                                      
#_________________________________________________________________________________________
    df = pd.DataFrame({'Names':name_list,'Specifications':specifications,'Prices':prices___})
    df['Brand'] = df['Names'].str.split().str.get(0)
    df['Engine'] = df.Specifications.str.split().str.get(0)
    df['Mileage'] = df.Specifications.str.split().str.get(2)
    df['Power'] = df.Specifications.str.split().str.get(4)                                        #step 5
    df['Weight'] = df.Specifications.str.split().str.get(6)    
    df['Prices'] = df.Prices.str.split().str.get(1)
    df.drop(columns=['Specifications'],axis=1,inplace=True)
#___________________________________________________________________________________________
    return df

# %% [markdown]
# Step 4 Explanation -
#
# 1. If we see the Thrid of coding in step 3 " OrderedDist.fromkeys() " i used for removeing "AD" string duplicate(repetation). and keep the value with its original position. Note - if we use " [*set()] it removes the duplicates but the values will be shuffled
#
# 2. After it will be convered into dist type so that i used " .key() " and conversted again into list type 4th line coding
#
# 3. and by " .remove() " method totally elimate the string value in the list

# %%
hero = page_url("https://www.bikewale.com/hero-bikes/")
ktm = page_url("https://www.bikewale.com/ktm-bikes/")
yamaha = page_url("https://www.bikewale.com/yamaha-bikes/")
honda=page_url('https://www.bikewale.com/honda-bikes/')
re = page_url('https://www.bikewale.com/royalenfield-bikes/')
tvs = page_url('https://www.bikewale.com/tvs-bikes/')
suzuki = page_url('https://www.bikewale.com/suzuki-bikes/')

# %%
Df = pd.concat((hero,ktm,yamaha,honda,re,tvs,suzuki),axis=0,ignore_index=True)

# %%
from IPython.display import display
with pd.option_context('display.max_rows',200):
    display(Df)
# Out:
#                                Names     Prices   Brand  Engine Mileage  \
# 0                 Hero Splendor Plus     70,924    Hero    97.2      60
# 1                     Hero HF Deluxe     54,355    Hero    97.2      65
# 2            Hero Splendor Plus Xtec     75,597    Hero    97.2      60
# 3                Hero Super Splendor     78,562    Hero   124.7      56
# 4                   Hero Xtreme 160R   1,19,621    Hero     163      46
# 5                       Hero Glamour     79,017    Hero   124.7      55
# 6                   Hero Passion Pro     73,296    Hero     110      55
# 7                  Hero Glamour Xtec     85,406    Hero   124.7      55
# 8                 Hero Xpulse 200 4V   1,37,158    Hero   199.6      40
# 9                  Hero Passion Xtec     76,851    Hero     110      55
# 10              Hero Pleasure + Xtec     76,065    Hero   110.9      50
# 11                   Hero Xpulse 200   1,27,090    Hero   199.6      40
# 12             Hero Destini 125 Xtec     73,202    Hero     125      45
# 13                  Hero Xtreme 200S   1,35,224    Hero   199.6      40
# 14             Hero Maestro Edge 110     70,766    Hero   110.9      40
# 15             Hero Maestro Edge 125     82,183    Hero   124.6      45
# 16          Hero Splendor iSmart 110     71,882    Hero   113.2      55
# 17                   Hero Pleasure +     67,880    Hero   110.9      50
# 18                  Hero Xpulse 200T   1,24,418    Hero   199.6      38
# 19                      KTM 200 Duke   1,89,148     KTM   199.5    34.5
# 20                      KTM 250 Duke   2,33,715     KTM  248.76      30
# 21                      KTM 125 Duke   1,74,822     KTM   124.7      40
# 22                      KTM 390 Duke   2,92,754     KTM  373.27      26
# 23                        KTM RC 200   2,10,326     KTM   199.5    34.5
# 24                        KTM RC 390   3,16,024     KTM     373    42.9
# 25                        KTM RC 125   1,83,326     KTM   124.7      40
# 26                 KTM 390 Adventure   3,37,440     KTM     373      28
# 27                 KTM 250 Adventure   2,37,894     KTM     248    29.5
# 28                     Yamaha R15 V4   1,79,749  Yamaha     155      45
# 29                   Yamaha MT 15 V2   1,64,404  Yamaha     155      45
# 30                    Yamaha FZ S FI   1,21,979  Yamaha     149      45
# 31                      Yamaha FZ FI   1,13,636  Yamaha     149      46
# 32                       Yamaha R15S   1,62,749  Yamaha     155      45
# 33                       Yamaha FZ25   1,47,681  Yamaha     249      38
# 34                       Yamaha FZ X   1,33,761  Yamaha     149      48
# 35                 Yamaha Ray ZR 125     82,261  Yamaha     125      52
# 36                Yamaha Fascino 125     78,443  Yamaha     125    50.5
# 37                  Yamaha Aerox 155   1,40,077  Yamaha     155    44.5
# 38                   Honda Activa 6G     73,181   Honda  109.51      48
# 39                      Honda SP 125     82,250   Honda     124      65
# 40                       Honda Shine     77,345   Honda     124      55
# 41                     Honda Unicorn   1,04,001   Honda   162.7      50
# 42                         Honda Dio     71,134   Honda  109.51      48
# 43                  Honda Activa 125     77,575   Honda     124      47
# 44                 Honda Hness CB350   1,98,236   Honda  348.36      35
# 45                  Honda Hornet 2.0   1,35,730   Honda   184.4      45
# 46                Honda CD 110 Dream     70,847   Honda  109.51      65
# 47                        Honda Livo     75,238   Honda  109.51      59
# 48                     Honda X-Blade   1,15,755   Honda  162.71      50
# 49                     Honda CB350RS   2,02,993   Honda  348.36      36
# 50                      Honda Grazia     81,740   Honda     124      45
# 51                      Honda CB300R   2,77,042   Honda     286      30
# 52                      Honda CB200X   1,47,815   Honda   184.4      42
# 53                      Honda CB300F   2,26,220   Honda  293.52    23.8
# 54       Honda CBR1000RR-R Fireblade  23,72,222   Honda   1,000     215
# 55                    Honda CBR 650R   9,34,812   Honda  648.72   85.82
# 56                 Honda Africa Twin  16,01,500   Honda   1,082   97.89
# 57                    Honda Goldwing  39,88,635   Honda   1,833   124.7
# 58                      Honda CB500X   5,80,612   Honda     471   46.93
# 59                      Honda CB650R   9,14,337   Honda  648.72   85.82
# 60          Royal Enfield Hunter 350   1,49,900   Royal     349      37
# 61         Royal Enfield Classic 350   1,90,229   Royal     349    34.5
# 62          Royal Enfield Meteor 350   2,01,365   Royal     349      35
# 63          Royal Enfield Bullet 350   1,47,910   Royal     346      38
# 64           Royal Enfield Himalayan   2,14,501   Royal     411      30
# 65  Royal Enfield Continental GT 650   3,04,970   Royal     648      25
# 66     Royal Enfield Interceptor 650   2,88,166   Royal     648      23
# 67           Royal Enfield Scram 411   2,03,085   Royal     411      32
# 68                TVS Apache RTR 160   1,14,004     TVS   159.7      45
# 69                    TVS Raider 125     89,733     TVS   124.8      57
# 70                         TVS Ronin   1,49,000     TVS     226      40
# 71             TVS Apache RTR 160 4V   1,12,616     TVS   159.7      45
# 72                     TVS Ntorq 125     83,987     TVS   124.8    40.5
# 73             TVS Apache RTR 200 4V   1,28,275     TVS  197.75      38
# 74                       TVS Jupiter     71,998     TVS   109.7      50
# 75                         TVS Sport     61,568     TVS   109.7      70
# 76                         TVS iQube     96,442     TVS      78     100
# 77                  TVS Apache RR310   2,64,980     TVS   312.2      30
# 78                   TVS Jupiter 125     83,147     TVS   124.8      50
# 79                        TVS Radeon     69,771     TVS   109.7      65
# 80                TVS Apache RTR 180   1,21,726     TVS   177.4      41
# 81                TVS Star City Plus     72,299     TVS   109.7      68
# 82               TVS Scooty Pep Plus     61,751     TVS    87.8      50
# 83              TVS XL100 Heavy Duty     46,233     TVS    99.7      55
# 84               TVS Scooty Zest 110     70,521     TVS   109.7      45
# 85                 TVS XL100 Comfort     44,555     TVS    99.7    51.5
# 86                 Suzuki Access 125     77,191  Suzuki     124      48
# 87                  Suzuki Gixxer SF   1,35,617  Suzuki     155      45
# 88         Suzuki Burgman Street 125     89,239  Suzuki     124      50
# 89                 Suzuki Avenis 125     89,759  Suzuki     124      52
# 90                     Suzuki Gixxer   1,30,553  Suzuki     155      45
# 91                   Suzuki Hayabusa  16,48,831  Suzuki   1,340   187.3
# 92                 Suzuki V-Strom SX   2,14,086  Suzuki     249    26.1
# 93              Suzuki Gixxer SF 250   1,88,534  Suzuki     249    35.5
# 94                 Suzuki Gixxer 250   1,77,767  Suzuki     249      35
# 95                     Suzuki Katana  13,66,893  Suzuki     999  150.19
# 96             Suzuki V-Strom 650 XT   8,92,905  Suzuki     645    69.7
#
#     Power Weight
# 0    7.91    112
# 1    7.91    109
# 2     7.9    112
# 3   10.72    122
# 4      15  138.5
# 5   10.72    122
# 6    9.02    117
# 7   10.72    123
# 8    18.8    158
# 9       9    118
# 10      8    104
# 11   17.8    157
# 12      9    114
# 13   17.8  154.5
# 14   8.04    112
# 15      9    112
# 16      9    116
# 17      8    104
# 18  17.83    154
# 19  24.67    159
# 20   29.6    170
# 21   14.3    159
# 22   42.9    171
# 23   25.4  160.6
# 24    172    NaN
# 25  14.75    162
# 26   42.3    163
# 27    177    NaN
# 28   18.1    142
# 29  18.14    139
# 30   12.2    137
# 31   12.2    135
# 32   18.1    142
# 33  20.51    153
# 34   12.2    139
# 35   8.04     98
# 36   8.04     99
# 37  14.79    126
# 38   7.68    107
# 39  10.72    117
# 40  10.59    114
# 41  12.73    140
# 42   7.65    105
# 43   8.18    111
# 44  20.78    181
# 45  17.03    142
# 46   8.67    112
# 47   8.67    115
# 48  13.67    143
# 49  20.78    179
# 50   8.14    108
# 51   31.1    146
# 52     17    147
# 53    153    NaN
# 54    201    NaN
# 55    211    NaN
# 56    239    NaN
# 57    390    NaN
# 58    199    NaN
# 59    206    NaN
# 60   20.2    177
# 61   20.2    195
# 62   20.2    191
# 63   19.1    186
# 64   24.3    199
# 65     47    198
# 66     47    202
# 67   24.3    185
# 68  15.31    139
# 69   11.2    123
# 70     20    159
# 71  17.39    145
# 72   9.25    118
# 73  20.54    152
# 74   7.37    107
# 75   8.18    110
# 76    117      5
# 77  33.52    174
# 78   8.04    108
# 79   8.08    116
# 80  16.56    141
# 81   8.08    115
# 82   5.36     93
# 83    4.3     88
# 84   7.71    103
# 85    4.3     86
# 86    8.6    104
# 87   13.4    148
# 88   8.58    110
# 89   8.58    106
# 90  13.41    141
# 91    266    NaN
# 92    167    NaN
# 93  26.13    161
# 94  26.13    156
# 95    217    NaN
# 96    216    NaN
